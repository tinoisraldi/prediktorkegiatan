# %%
# import numpy as np
# import pandas as pd 
# import matplotlib.pyplot as plt 
# import matplotlib.colors as mcolors
import random
import datetime
# import library pandas
import pandas as pd

# Import library numpy
import numpy as np

# Import library matplotlib dan seaborn untuk visualisasi
import matplotlib.pyplot as plt
import seaborn as sns

# Import Module LinearRegression digunakan untuk memanggil algoritma Linear Regression.
from sklearn.linear_model import LinearRegression

# import Module train_test_split digunakan untuk membagi data kita menjadi training dan testing set.
from sklearn.model_selection import train_test_split

# import modul mean_absolute_error dari library sklearn
from sklearn.metrics import mean_absolute_error

#import math agar program dapat menggunakan semua fungsi yang ada pada modul math.(ex:sqrt)
import math

#extract model
import joblib

# me-non aktifkan peringatan pada python
import warnings 
warnings.simplefilter('ignore')

# %%
# check data Mobility Report
mobility = pd.read_csv('D:/TI/AI/Data Science/Covid19/JAKARTA MOBILITY REPORT.csv')
#drop data yang ga kepake
mobility = mobility.drop(mobility.columns[[0, 1,2,3,4,5,6,7]], axis=1)
mobility
# Out:
#            date  retail_and_recreation_percent_change_from_baseline  \
# 0      1/1/2021                                                -46
# 1      1/2/2021                                                -39
# 2      1/3/2021                                                -40
# 3      1/4/2021                                                -29
# 4      1/5/2021                                                -32
# ..          ...                                                ...
# 284  10/12/2021                                                -16
# 285  10/13/2021                                                -15
# 286  10/14/2021                                                -15
# 287  10/15/2021                                                -12
# 288  10/16/2021                                                -15
#
#      grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                  -27
# 1                                                  -15
# 2                                                  -19
# 3                                                   -5
# 4                                                   -9
# ..                                                 ...
# 284                                                  4
# 285                                                  4
# 286                                                  5
# 287                                                  8
# 288                                                  8
#
#      parks_percent_change_from_baseline  \
# 0                                   -51
# 1                                   -50
# 2                                   -58
# 3                                   -50
# 4                                   -53
# ..                                  ...
# 284                                 -35
# 285                                 -33
# 286                                 -32
# 287                                 -25
# 288                                 -32
#
#      transit_stations_percent_change_from_baseline  \
# 0                                              -61
# 1                                              -41
# 2                                              -34
# 3                                              -39
# 4                                              -39
# ..                                             ...
# 284                                            -33
# 285                                            -32
# 286                                            -33
# 287                                            -31
# 288                                            -23
#
#      workplaces_percent_change_from_baseline  \
# 0                                        -73
# 1                                        -33
# 2                                        -15
# 3                                        -32
# 4                                        -33
# ..                                       ...
# 284                                      -30
# 285                                      -28
# 286                                      -28
# 287                                      -26
# 288                                      -16
#
#      residential_percent_change_from_baseline
# 0                                          22
# 1                                          11
# 2                                           9
# 3                                          13
# 4                                          14
# ..                                        ...
# 284                                        10
# 285                                         9
# 286                                        10
# 287                                        10
# 288                                         5
#
# [289 rows x 7 columns]

# %%
# check data Mobility Report
mobility = pd.read_csv('D:/TI/AI/Data Science/Covid19/JAKARTA MOBILITY REPORT.csv')
#drop data yang ga kepake
mobility = mobility.drop(mobility.columns[[0, 1,2,3,4,5,6,7]], axis=1)

mobility
# Out:
#            date  retail_and_recreation_percent_change_from_baseline  \
# 0      1/1/2021                                                -46
# 1      1/2/2021                                                -39
# 2      1/3/2021                                                -40
# 3      1/4/2021                                                -29
# 4      1/5/2021                                                -32
# ..          ...                                                ...
# 284  10/12/2021                                                -16
# 285  10/13/2021                                                -15
# 286  10/14/2021                                                -15
# 287  10/15/2021                                                -12
# 288  10/16/2021                                                -15
#
#      grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                  -27
# 1                                                  -15
# 2                                                  -19
# 3                                                   -5
# 4                                                   -9
# ..                                                 ...
# 284                                                  4
# 285                                                  4
# 286                                                  5
# 287                                                  8
# 288                                                  8
#
#      parks_percent_change_from_baseline  \
# 0                                   -51
# 1                                   -50
# 2                                   -58
# 3                                   -50
# 4                                   -53
# ..                                  ...
# 284                                 -35
# 285                                 -33
# 286                                 -32
# 287                                 -25
# 288                                 -32
#
#      transit_stations_percent_change_from_baseline  \
# 0                                              -61
# 1                                              -41
# 2                                              -34
# 3                                              -39
# 4                                              -39
# ..                                             ...
# 284                                            -33
# 285                                            -32
# 286                                            -33
# 287                                            -31
# 288                                            -23
#
#      workplaces_percent_change_from_baseline  \
# 0                                        -73
# 1                                        -33
# 2                                        -15
# 3                                        -32
# 4                                        -33
# ..                                       ...
# 284                                      -30
# 285                                      -28
# 286                                      -28
# 287                                      -26
# 288                                      -16
#
#      residential_percent_change_from_baseline
# 0                                          22
# 1                                          11
# 2                                           9
# 3                                          13
# 4                                          14
# ..                                        ...
# 284                                        10
# 285                                         9
# 286                                        10
# 287                                        10
# 288                                         5
#
# [289 rows x 7 columns]

# %%
# cek range tanggal yang akan diambil dari 8/1/2021 hingga akhir
mobility['date'] = pd.to_datetime(mobility['date'])
start_date = '1/1/2021'
end_date = '2021-10-16'
mask = (mobility['date'] >= start_date)
mobility = mobility.loc[mask]
mobility = mobility.reset_index(drop=True)
mobility
# Out:
#           date  retail_and_recreation_percent_change_from_baseline  \
# 0   2021-01-01                                                -46
# 1   2021-01-02                                                -39
# 2   2021-01-03                                                -40
# 3   2021-01-04                                                -29
# 4   2021-01-05                                                -32
# ..         ...                                                ...
# 284 2021-10-12                                                -16
# 285 2021-10-13                                                -15
# 286 2021-10-14                                                -15
# 287 2021-10-15                                                -12
# 288 2021-10-16                                                -15
#
#      grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                  -27
# 1                                                  -15
# 2                                                  -19
# 3                                                   -5
# 4                                                   -9
# ..                                                 ...
# 284                                                  4
# 285                                                  4
# 286                                                  5
# 287                                                  8
# 288                                                  8
#
#      parks_percent_change_from_baseline  \
# 0                                   -51
# 1                                   -50
# 2                                   -58
# 3                                   -50
# 4                                   -53
# ..                                  ...
# 284                                 -35
# 285                                 -33
# 286                                 -32
# 287                                 -25
# 288                                 -32
#
#      transit_stations_percent_change_from_baseline  \
# 0                                              -61
# 1                                              -41
# 2                                              -34
# 3                                              -39
# 4                                              -39
# ..                                             ...
# 284                                            -33
# 285                                            -32
# 286                                            -33
# 287                                            -31
# 288                                            -23
#
#      workplaces_percent_change_from_baseline  \
# 0                                        -73
# 1                                        -33
# 2                                        -15
# 3                                        -32
# 4                                        -33
# ..                                       ...
# 284                                      -30
# 285                                      -28
# 286                                      -28
# 287                                      -26
# 288                                      -16
#
#      residential_percent_change_from_baseline
# 0                                          22
# 1                                          11
# 2                                           9
# 3                                          13
# 4                                          14
# ..                                        ...
# 284                                        10
# 285                                         9
# 286                                        10
# 287                                        10
# 288                                         5
#
# [289 rows x 7 columns]

# %%
mobility['retail_and_recreation_percent_change_from_baseline']
# Out:
# 0     -46
# 1     -39
# 2     -40
# 3     -29
# 4     -32
#        ..
# 284   -16
# 285   -15
# 286   -15
# 287   -12
# 288   -15
# Name: retail_and_recreation_percent_change_from_baseline, Length: 289, dtype: int64

# %% [markdown]
# # asdas

# %%
# import data Rapid test anti gen dengan sheet RDT Ag 
rdt_ag = pd.read_excel('D:/TI/AI/Data Science/Covid19/Covid19_Jakarta.xlsx',sheet_name='RDT Ag')
rdt_ag
# Out:
#        No.                  EIS Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0      NaN                  Tgl    Positif    Negatif      Total
# 1      1.0  2021-01-01 00:00:00         76       1116       1192
# 2      2.0  2021-01-02 00:00:00         76       1116       1192
# 3      3.0  2021-01-03 00:00:00        100       1699       1799
# 4      4.0  2021-01-04 00:00:00        100       1699       1799
# ..     ...                  ...        ...        ...        ...
# 329  329.0  2021-11-25 00:00:00       8164     132247     140411
# 330  330.0  2021-11-26 00:00:00       8166     132475     140641
# 331  331.0  2021-11-27 00:00:00       8166     132631     140797
# 332  332.0  2021-11-28 00:00:00       8169     132773     140942
# 333  333.0  2021-11-29 00:00:00       8169     132878     141047
#
#           Unnamed: 5      NAR Unnamed: 7 Unnamed: 8       Unnamed: 9  ...  \
# 0    Positivity Rate  Positif    Negatif      Total  Positivity Rate  ...
# 1          0.0637584        0          0          0              NaN  ...
# 2          0.0637584        0          0          0              NaN  ...
# 3          0.0555864        0          0          0              NaN  ...
# 4          0.0555864        0          0          0              NaN  ...
# ..               ...      ...        ...        ...              ...  ...
# 329        0.0581436    48273    3219030    3267303        0.0147746  ...
# 330        0.0580627    48288    3263423    3311711         0.014581  ...
# 331        0.0579984    48293    3307299    3355592        0.0143918  ...
# 332          0.05796    48297    3342704    3391001        0.0142427  ...
# 333        0.0579169    48302    3380286    3428588         0.014088  ...
#
#     Unnamed: 12      Unnamed: 13 Total DKI Jakarta      Unnamed: 15  \
# 0         Total  Positivity Rate        Tes Harian  Positif  Harian
# 1             0              NaN              1192               76
# 2             0              NaN                 0                0
# 3             0              NaN               607               24
# 4             0              NaN                 0                0
# ..          ...              ...               ...              ...
# 329        1016        0.0413386             44435                8
# 330        1016        0.0413386             44638               17
# 331        1016        0.0413386             44037                5
# 332        1016        0.0413386             35554                7
# 333        1016        0.0413386             37692                5
#
#         Unnamed: 16             Unnamed: 17      Unnamed: 18  \
# 0    Negatif Harian  Positivity Rate Harian  Total Kumulatif
# 1              1116               0.0637584             1192
# 2                 0                     NaN             1192
# 3               583               0.0395387             1799
# 4                 0                     NaN             1799
# ..              ...                     ...              ...
# 329           44427             0.000180038          3408730
# 330           44621             0.000380841          3453368
# 331           44032             0.000113541          3497405
# 332           35547             0.000196884          3532959
# 333           37687             0.000132654          3570651
#
#            Unnamed: 19        Unnamed: 20                Unnamed: 21
# 0    Positif Kumulatif  Negatif Kumulatif  Positivity Rate Kumulatif
# 1                   76               1116                  0.0637584
# 2                   76               1116                  0.0637584
# 3                  100               1699                  0.0555864
# 4                  100               1699                  0.0555864
# ..                 ...                ...                        ...
# 329              56479            3352251                  0.0165689
# 330              56496            3396872                  0.0163597
# 331              56501            3440904                  0.0161551
# 332              56508            3476451                  0.0159945
# 333              56513            3514138                  0.0158271
#
# [334 rows x 22 columns]

# %%
# mengganti header dengan column dikarenakan nama column masih tidak sesuai
header_row = 0
rdt_ag.columns = rdt_ag.iloc[header_row]

# %%
# drop column 0 agar tidak duplikat
rdt_ag = rdt_ag.drop(0)

# %%
# mereset index akibat penghilangan column
rdt_ag = rdt_ag.reset_index(drop=True)
rdt_ag
# Out:
# 0      NaN                  Tgl Positif Negatif   Total Positivity Rate  \
# 0      1.0  2021-01-01 00:00:00      76    1116    1192       0.0637584
# 1      2.0  2021-01-02 00:00:00      76    1116    1192       0.0637584
# 2      3.0  2021-01-03 00:00:00     100    1699    1799       0.0555864
# 3      4.0  2021-01-04 00:00:00     100    1699    1799       0.0555864
# 4      5.0  2021-01-05 00:00:00     100    1699    1799       0.0555864
# ..     ...                  ...     ...     ...     ...             ...
# 328  329.0  2021-11-25 00:00:00    8164  132247  140411       0.0581436
# 329  330.0  2021-11-26 00:00:00    8166  132475  140641       0.0580627
# 330  331.0  2021-11-27 00:00:00    8166  132631  140797       0.0579984
# 331  332.0  2021-11-28 00:00:00    8169  132773  140942         0.05796
# 332  333.0  2021-11-29 00:00:00    8169  132878  141047       0.0579169
#
# 0   Positif  Negatif    Total Positivity Rate  ... Total Positivity Rate  \
# 0         0        0        0             NaN  ...     0             NaN
# 1         0        0        0             NaN  ...     0             NaN
# 2         0        0        0             NaN  ...     0             NaN
# 3         0        0        0             NaN  ...     0             NaN
# 4         0        0        0             NaN  ...     0             NaN
# ..      ...      ...      ...             ...  ...   ...             ...
# 328   48273  3219030  3267303       0.0147746  ...  1016       0.0413386
# 329   48288  3263423  3311711        0.014581  ...  1016       0.0413386
# 330   48293  3307299  3355592       0.0143918  ...  1016       0.0413386
# 331   48297  3342704  3391001       0.0142427  ...  1016       0.0413386
# 332   48302  3380286  3428588        0.014088  ...  1016       0.0413386
#
# 0   Tes Harian Positif  Harian Negatif Harian Positivity Rate Harian  \
# 0         1192              76           1116              0.0637584
# 1            0               0              0                    NaN
# 2          607              24            583              0.0395387
# 3            0               0              0                    NaN
# 4            0               0              0                    NaN
# ..         ...             ...            ...                    ...
# 328      44435               8          44427            0.000180038
# 329      44638              17          44621            0.000380841
# 330      44037               5          44032            0.000113541
# 331      35554               7          35547            0.000196884
# 332      37692               5          37687            0.000132654
#
# 0   Total Kumulatif Positif Kumulatif Negatif Kumulatif  \
# 0              1192                76              1116
# 1              1192                76              1116
# 2              1799               100              1699
# 3              1799               100              1699
# 4              1799               100              1699
# ..              ...               ...               ...
# 328         3408730             56479           3352251
# 329         3453368             56496           3396872
# 330         3497405             56501           3440904
# 331         3532959             56508           3476451
# 332         3570651             56513           3514138
#
# 0   Positivity Rate Kumulatif
# 0                   0.0637584
# 1                   0.0637584
# 2                   0.0555864
# 3                   0.0555864
# 4                   0.0555864
# ..                        ...
# 328                 0.0165689
# 329                 0.0163597
# 330                 0.0161551
# 331                 0.0159945
# 332                 0.0158271
#
# [333 rows x 22 columns]

# %%
# mengecek tipe data dari tiap tiap column
rdt_ag.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   nan                        333 non-null    float64
#  1   Tgl                        333 non-null    object
#  2   Positif                    333 non-null    object
#  3   Negatif                    333 non-null    object
#  4   Total                      333 non-null    object
#  5   Positivity Rate            333 non-null    object
#  6   Positif                    333 non-null    object
#  7   Negatif                    333 non-null    object
#  8   Total                      333 non-null    object
#  9   Positivity Rate            276 non-null    object
#  10  Positif                    333 non-null    object
#  11  Negatif                    333 non-null    object
#  12  Total                      333 non-null    object
#  13  Positivity Rate            277 non-null    object
#  14  Tes Harian                 333 non-null    object
#  15  Positif  Harian            333 non-null    object
#  16  Negatif Harian             333 non-null    object
#  17  Positivity Rate Harian     324 non-null    object
#  18  Total Kumulatif            333 non-null    object
#  19  Positif Kumulatif          333 non-null    object
#  20  Negatif Kumulatif          333 non-null    object
#  21  Positivity Rate Kumulatif  333 non-null    object
# dtypes: float64(1), object(21)
# memory usage: 57.4+ KB

# %%
# mengubah tipe data Positivity Rate Kumulatif menjadi numeric agar dapat melakukan regresi
# rdt_ag.astype({'Positivity Rate Kumulatif':'float64'}).dtypes

rdt_ag['Positivity Rate Kumulatif'] = pd.to_numeric(rdt_ag['Positivity Rate Kumulatif'])
# rdt_ag.info()

# %%
# mengambil tanggal dengan range tanggal dari 2021-08-01 hingga 10/16/2021
rdt_ag['Tgl'] = pd.to_datetime(rdt_ag['Tgl'])
start_date = '1/1/2021'
end_date = '2021-10-16'
mask = (rdt_ag['Tgl'] >= start_date) & (rdt_ag['Tgl'] <= end_date)
rdt_ag = rdt_ag.loc[mask]
rdt_ag = rdt_ag.reset_index(drop=True)
rdt_ag
# Out:
# 0      NaN        Tgl Positif Negatif   Total Positivity Rate Positif  \
# 0      1.0 2021-01-01      76    1116    1192       0.0637584       0
# 1      2.0 2021-01-02      76    1116    1192       0.0637584       0
# 2      3.0 2021-01-03     100    1699    1799       0.0555864       0
# 3      4.0 2021-01-04     100    1699    1799       0.0555864       0
# 4      5.0 2021-01-05     100    1699    1799       0.0555864       0
# ..     ...        ...     ...     ...     ...             ...     ...
# 284  285.0 2021-10-12    8151  127162  135313       0.0602381   47837
# 285  286.0 2021-10-13    8151  127409  135560       0.0601284   47848
# 286  287.0 2021-10-14    8155  127553  135708       0.0600923   47873
# 287  288.0 2021-10-15    8155  127742  135897       0.0600087   47886
# 288  289.0 2021-10-16    8155  127844  135999       0.0599637   47912
#
# 0    Negatif    Total Positivity Rate  ... Total Positivity Rate Tes Harian  \
# 0          0        0             NaN  ...     0             NaN       1192
# 1          0        0             NaN  ...     0             NaN          0
# 2          0        0             NaN  ...     0             NaN        607
# 3          0        0             NaN  ...     0             NaN          0
# 4          0        0             NaN  ...     0             NaN          0
# ..       ...      ...             ...  ...   ...             ...        ...
# 284  1870945  1918782       0.0249309  ...  1016       0.0413386      30504
# 285  1899130  1946978       0.0245755  ...  1016       0.0413386      28443
# 286  1931678  1979551       0.0241838  ...  1016       0.0413386      32721
# 287  1957417  2005303       0.0238797  ...  1016       0.0413386      25941
# 288  1990943  2038855       0.0234995  ...  1016       0.0413386      33654
#
# 0   Positif  Harian Negatif Harian Positivity Rate Harian Total Kumulatif  \
# 0                76           1116              0.0637584            1192
# 1                 0              0                    NaN            1192
# 2                24            583              0.0395387            1799
# 3                 0              0                    NaN            1799
# 4                 0              0                    NaN            1799
# ..              ...            ...                    ...             ...
# 284              25          30479            0.000819565         2055111
# 285              11          28432            0.000386738         2083554
# 286              29          32692            0.000886281         2116275
# 287              13          25928            0.000501137         2142216
# 288              26          33628            0.000772568         2175870
#
# 0   Positif Kumulatif Negatif Kumulatif Positivity Rate Kumulatif
# 0                  76              1116                  0.063758
# 1                  76              1116                  0.063758
# 2                 100              1699                  0.055586
# 3                 100              1699                  0.055586
# 4                 100              1699                  0.055586
# ..                ...               ...                       ...
# 284             56030           1999081                  0.027264
# 285             56041           2027513                  0.026897
# 286             56070           2060205                  0.026495
# 287             56083           2086133                  0.026180
# 288             56109           2119761                  0.025787
#
# [289 rows x 22 columns]

# %% [markdown]
# # cek rdt dan mobilitas

# %%
plt.scatter(rdt_ag['Positivity Rate Kumulatif'], mobility['retail_and_recreation_percent_change_from_baseline'])
plt.xlabel('Positivity Rate Kumulatif')
plt.ylabel('pertumbuhan retail')
plt.title('positif rate vs pertumbuhan retail')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Prepare data
# Pertama, buat variabel x dan y.
x = rdt_ag['Positivity Rate Kumulatif'].values.reshape(-1,1)
y = mobility['retail_and_recreation_percent_change_from_baseline'].values.reshape(-1,1)
# y = y.fillna()

# %%
#cari mean
x_mean = np.mean(x)
y_mean = np.mean(y)
print('nilai mean var x: ', x_mean,'\n'
      'nilai mean var y: ', y_mean)
# Out:
# nilai mean var x:  0.049248842598038516
# nilai mean var y:  -27.66089965397924

# %%
atas = sum((x - x_mean)*(y - y_mean))
bawah = math.sqrt((sum((x - x_mean)**2)) * (sum((y - y_mean)**2)))
correlation = atas/bawah
print('Nilai Correlation Coefficient: ', correlation)
# Out:
# Nilai Correlation Coefficient:  [-0.68793685]

# %%
# slope
# Slope adalah tingkat kemiringan garis, intercept 
# adalah jarak titik y pada garis dari titik 0
variance = sum((x - x_mean)**2)
covariance = sum((x - x_mean) * (y - y_mean))
theta_1 = covariance/variance
print('Nilai theta_1: ',theta_1)
# Out:
# Nilai theta_1:  [-347.58560982]

# %% [markdown]
# # yang ini baru nyobain make regressor

# %%
# split data testing dan training
x_train,x_test,y_train,y_test = train_test_split(x, y, train_size = 0.8, test_size = 0.2, random_state = 100)

# %%
regressor = LinearRegression()

# %%
#fit data training dengan label
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#cek koefisien dengan nilai interceptnya
print(regressor.coef_)
print(regressor.intercept_)
# Out:
# [[-349.75179719]]
# [-10.259895]

# %%
# cek akurasi dari testing dan label
print("tingkat akurasinya :",regressor.score(x_test,y_test))
# Out:
# tingkat akurasinya : 0.3942444223073738

# %%
# hasil nilai korelasinya
print('Correlation: ', math.sqrt(regressor.score(x_test,y_test)))
# Out:
# Correlation:  0.6278888614296114

# %%
# visualisasi regressor
y_prediksi = regressor.predict(x_test)

plt.scatter(rdt_ag['Positivity Rate Kumulatif'], mobility['retail_and_recreation_percent_change_from_baseline'])
plt.plot(x_test, y_prediksi, c='r')
plt.xlabel('positif')
plt.ylabel('pertumbuhan retail')
plt.title('positif vs pertumbuhan retail')
# Out:
# Text(0.5, 1.0, 'positif vs pertumbuhan retail')

# %%
# coba test prediksi
print('nilai prediksi pertumbuhan retail dengan positif 0.03 : ',regressor.predict([[0.03]]))
print('nilai prediksi pertumbuhan retail dengan positif 0.02 : ',regressor.predict([[0.02]]))
print('nilai prediksi pertumbuhan retail dengan positif 0.07 : ',regressor.predict([[0.07]]))
print('nilai prediksi pertumbuhan retail dengan positif 0.09 : ',regressor.predict([[0.09]]))
# Out:
# nilai prediksi pertumbuhan retail dengan positif 0.03 :  [[-20.75244892]]
# nilai prediksi pertumbuhan retail dengan positif 0.02 :  [[-17.25493094]]
# nilai prediksi pertumbuhan retail dengan positif 0.07 :  [[-34.7425208]]
# nilai prediksi pertumbuhan retail dengan positif 0.09 :  [[-41.73755675]]

# %%
# coba nampilin test dan label dan prediksi
np_table = np.concatenate((x_test,y_test,y_prediksi), axis=1)
new_dataframe = pd.DataFrame(data=np_table, columns=['x_test | positif','y_test | label','y_predict | predukssi pertumbuhan'])

# %%
new_dataframe
# Out:
#     x_test | positif  y_test | label  y_predict | predukssi pertumbuhan
# 0           0.034325           -25.0                         -22.265019
# 1           0.028650           -27.0                         -20.280117
# 2           0.037033           -35.0                         -23.212092
# 3           0.038929           -16.0                         -23.875502
# 4           0.045958           -24.0                         -26.333741
# 5           0.058729           -30.0                         -30.800564
# 6           0.029091           -34.0                         -20.434529
# 7           0.061240           -44.0                         -31.678840
# 8           0.026495           -15.0                         -19.526452
# 9           0.045284           -24.0                         -26.098187
# 10          0.053997           -28.0                         -29.145616
# 11          0.034077           -18.0                         -22.178401
# 12          0.058839           -34.0                         -30.838825
# 13          0.060531           -40.0                         -31.430560
# 14          0.066134           -29.0                         -33.390309
# 15          0.049911           -43.0                         -27.716226
# 16          0.030690           -17.0                         -20.993838
# 17          0.043874           -17.0                         -25.605044
# 18          0.025059           -14.0                         -19.024161
# 19          0.081648           -34.0                         -38.816431
# 20          0.056954           -27.0                         -30.179683
# 21          0.063352           -26.0                         -32.417473
# 22          0.044304           -26.0                         -25.755170
# 23          0.060666           -31.0                         -31.477834
# 24          0.027968           -21.0                         -20.041825
# 25          0.054860           -51.0                         -29.447177
# 26          0.024366           -19.0                         -18.781890
# 27          0.038257           -20.0                         -23.640422
# 28          0.024926           -16.0                         -18.977972
# 29          0.073119           -28.0                         -35.833410
# 30          0.057891           -28.0                         -30.507275
# 31          0.034513           -26.0                         -22.330981
# 32          0.060354           -36.0                         -31.368708
# 33          0.075094           -39.0                         -36.524249
# 34          0.038925           -32.0                         -23.874059
# 35          0.029910           -25.0                         -20.721065
# 36          0.053203           -28.0                         -28.867769
# 37          0.030294           -20.0                         -20.855306
# 38          0.026881           -20.0                         -19.661680
# 39          0.061784           -34.0                         -31.869003
# 40          0.066667           -29.0                         -33.576681
# 41          0.034568           -20.0                         -22.349946
# 42          0.063758           -39.0                         -32.559506
# 43          0.088357           -48.0                         -41.162970
# 44          0.031609           -15.0                         -21.315264
# 45          0.031913            -9.0                         -21.421482
# 46          0.041633           -28.0                         -24.821070
# 47          0.087625           -38.0                         -40.906827
# 48          0.031995           -28.0                         -21.450222
# 49          0.078063           -27.0                         -37.562670
# 50          0.038313           -19.0                         -23.660074
# 51          0.068762           -24.0                         -34.309665
# 52          0.052935           -26.0                         -28.774061
# 53          0.036792           -20.0                         -23.127796
# 54          0.025001           -24.0                         -19.003896
# 55          0.058154           -44.0                         -30.599217
# 56          0.060091           -50.0                         -31.276832
# 57          0.029112           -27.0                         -20.441848

# %%
from sklearn import metrics  
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_prediksi))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_prediksi))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_prediksi)))
# Out:
# Mean Absolute Error: 5.655211733431568
# Mean Squared Error: 53.06519699803668
# Root Mean Squared Error: 7.284586261280505

# %%
filename = "model.sav"
joblib.dump(regressor.fit(x_train, y_train), filename)
# Out:
# ['model.sav']

# %%
loaded_model = joblib.load(filename)

# %%
loaded_model.predict([[0.01]])
# Out:
# array([[-13.75741297]])
